# %%
import json_helper as jh
import pandas as pd
import json
import os
import numpy as np

# %%
def read_json(file_path: str):
    with open(file_path) as f:
        json_input = json.load(f)
    return json_input

def read_all_json_files(JSON_ROOT):
    result = []
    for dirpath, dirname, filenames in os.walk(JSON_ROOT):
        
        for f in filenames:
            if f.endswith('.json'):
                json_content = read_json(os.path.join(JSON_ROOT, f))
                for i in json_content['results']:
                    i['source'] = f
                    result.append(i)
    df_location = pd.DataFrame(result)
    return df_location

# %%
# display a summary of df_daily_summaries
df_daily_summaries = read_all_json_files('./daily_summaries')

# %%
df_daily_summaries
# Out:
#                      date datatype            station attributes  value  \
# 0     2018-01-27T00:00:00     SNOW  GHCND:US1DENC0031       ,,N,      0
# 1     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0032       ,,N,      0
# 2     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0033       ,,N,      0
# 3     2018-01-27T00:00:00     SNOW  GHCND:US1DENC0033       ,,N,      0
# 4     2018-01-27T00:00:00     PRCP  GHCND:US1DENC0035       ,,N,      0
# ...                   ...      ...                ...        ...    ...
# 1164  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0013       ,,N,      0
# 1165  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0013       ,,N,      0
# 1166  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0028       ,,N,      0
# 1167  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0028       ,,N,      0
# 1168  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0031       ,,N,      0
#
#                                          source
# 0     daily_summaries_FIPS10003_jan_2018_1.json
# 1     daily_summaries_FIPS10003_jan_2018_1.json
# 2     daily_summaries_FIPS10003_jan_2018_1.json
# 3     daily_summaries_FIPS10003_jan_2018_1.json
# 4     daily_summaries_FIPS10003_jan_2018_1.json
# ...                                         ...
# 1164  daily_summaries_FIPS10003_jan_2018_0.json
# 1165  daily_summaries_FIPS10003_jan_2018_0.json
# 1166  daily_summaries_FIPS10003_jan_2018_0.json
# 1167  daily_summaries_FIPS10003_jan_2018_0.json
# 1168  daily_summaries_FIPS10003_jan_2018_0.json
#
# [1169 rows x 6 columns]

# %% [markdown]
# How many stations are there in total for FIPS10003

# %%
# 
df_daily_summaries['station'].nunique()
# Out:
# 17

# %% [markdown]
# Create a DataFrame called temps_max that only contains the entries from df_daily_summaries where the datatype column is equal to TMAX. This DataFrame should only retain the date column and the value column.

# %%
temps_max = df_daily_summaries[df_daily_summaries['datatype'].str.contains('TMAX')]

# %%
temps_max
# Out:
#                      date datatype            station attributes  value  \
# 17    2018-01-27T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    150
# 46    2018-01-28T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    133
# 88    2018-01-29T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     78
# 124   2018-01-30T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     39
# 163   2018-01-31T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400      6
# 204   2018-01-01T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -60
# 244   2018-01-02T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -38
# 286   2018-01-03T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     -5
# 334   2018-01-04T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -21
# 374   2018-01-05T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -82
# 406   2018-01-06T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -88
# 442   2018-01-07T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -71
# 478   2018-01-08T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400      6
# 505   2018-01-09T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     78
# 542   2018-01-10T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     56
# 580   2018-01-11T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    133
# 614   2018-01-12T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    167
# 655   2018-01-13T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    139
# 692   2018-01-14T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -32
# 734   2018-01-15T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400      0
# 777   2018-01-16T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     56
# 823   2018-01-17T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     22
# 862   2018-01-18T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     22
# 900   2018-01-19T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     83
# 937   2018-01-20T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    139
# 977   2018-01-21T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    117
# 1008  2018-01-22T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    156
# 1041  2018-01-23T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    172
# 1077  2018-01-24T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     72
# 1113  2018-01-25T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     28
# 1150  2018-01-26T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     39
#
#                                          source
# 17    daily_summaries_FIPS10003_jan_2018_1.json
# 46    daily_summaries_FIPS10003_jan_2018_1.json
# 88    daily_summaries_FIPS10003_jan_2018_1.json
# 124   daily_summaries_FIPS10003_jan_2018_1.json
# 163   daily_summaries_FIPS10003_jan_2018_1.json
# 204   daily_summaries_FIPS10003_jan_2018_0.json
# 244   daily_summaries_FIPS10003_jan_2018_0.json
# 286   daily_summaries_FIPS10003_jan_2018_0.json
# 334   daily_summaries_FIPS10003_jan_2018_0.json
# 374   daily_summaries_FIPS10003_jan_2018_0.json
# 406   daily_summaries_FIPS10003_jan_2018_0.json
# 442   daily_summaries_FIPS10003_jan_2018_0.json
# 478   daily_summaries_FIPS10003_jan_2018_0.json
# 505   daily_summaries_FIPS10003_jan_2018_0.json
# 542   daily_summaries_FIPS10003_jan_2018_0.json
# 580   daily_summaries_FIPS10003_jan_2018_0.json
# 614   daily_summaries_FIPS10003_jan_2018_0.json
# 655   daily_summaries_FIPS10003_jan_2018_0.json
# 692   daily_summaries_FIPS10003_jan_2018_0.json
# 734   daily_summaries_FIPS10003_jan_2018_0.json
# 777   daily_summaries_FIPS10003_jan_2018_0.json
# 823   daily_summaries_FIPS10003_jan_2018_0.json
# 862   daily_summaries_FIPS10003_jan_2018_0.json
# 900   daily_summaries_FIPS10003_jan_2018_0.json
# 937   daily_summaries_FIPS10003_jan_2018_0.json
# 977   daily_summaries_FIPS10003_jan_2018_0.json
# 1008  daily_summaries_FIPS10003_jan_2018_0.json
# 1041  daily_summaries_FIPS10003_jan_2018_0.json
# 1077  daily_summaries_FIPS10003_jan_2018_0.json
# 1113  daily_summaries_FIPS10003_jan_2018_0.json
# 1150  daily_summaries_FIPS10003_jan_2018_0.json

# %% [markdown]
# How many entries are there in the temps_max DataFrame? What are the mean, min, and max values?

# %%
# 
temps_max.count()
# Out:
# date          31
# datatype      31
# station       31
# attributes    31
# value         31
# source        31
# dtype: int64

# %%
numOfEntries = temps_max.shape[0]
 
print('Number of Entries in temps_max : ' , numOfEntries)
# Out:
# Number of Entries in temps_max :  31

# %% [markdown]
# Let's graph this DataFrame so we can get a visual representation for this information.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = temps_max['date'].str[8:10]
y = temps_max['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Max Temperatues Jan 2018')]

# %% [markdown]
# Create a DataFrame called temps_min that only contains the entries from df_daily_summaries where the datatype column is equal to TMIN. This DataFrame should only retain the date column and the value column.

# %%
# 
temps_min = df_daily_summaries[df_daily_summaries['datatype'].str.contains('TMIN')]

# %%
temps_min
# Out:
#                      date datatype            station attributes  value  \
# 18    2018-01-27T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -49
# 47    2018-01-28T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     72
# 89    2018-01-29T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     33
# 125   2018-01-30T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -55
# 164   2018-01-31T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -93
# 205   2018-01-01T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -149
# 245   2018-01-02T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -116
# 287   2018-01-03T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -132
# 335   2018-01-04T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -93
# 375   2018-01-05T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -121
# 407   2018-01-06T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -138
# 443   2018-01-07T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -166
# 479   2018-01-08T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -105
# 506   2018-01-09T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -60
# 543   2018-01-10T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -49
# 581   2018-01-11T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     33
# 615   2018-01-12T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     83
# 656   2018-01-13T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -71
# 693   2018-01-14T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -105
# 735   2018-01-15T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -88
# 778   2018-01-16T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -16
# 824   2018-01-17T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -77
# 863   2018-01-18T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -99
# 901   2018-01-19T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -66
# 938   2018-01-20T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -38
# 978   2018-01-21T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -32
# 1009  2018-01-22T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     39
# 1042  2018-01-23T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     44
# 1078  2018-01-24T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400      6
# 1114  2018-01-25T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -38
# 1151  2018-01-26T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -66
#
#                                          source
# 18    daily_summaries_FIPS10003_jan_2018_1.json
# 47    daily_summaries_FIPS10003_jan_2018_1.json
# 89    daily_summaries_FIPS10003_jan_2018_1.json
# 125   daily_summaries_FIPS10003_jan_2018_1.json
# 164   daily_summaries_FIPS10003_jan_2018_1.json
# 205   daily_summaries_FIPS10003_jan_2018_0.json
# 245   daily_summaries_FIPS10003_jan_2018_0.json
# 287   daily_summaries_FIPS10003_jan_2018_0.json
# 335   daily_summaries_FIPS10003_jan_2018_0.json
# 375   daily_summaries_FIPS10003_jan_2018_0.json
# 407   daily_summaries_FIPS10003_jan_2018_0.json
# 443   daily_summaries_FIPS10003_jan_2018_0.json
# 479   daily_summaries_FIPS10003_jan_2018_0.json
# 506   daily_summaries_FIPS10003_jan_2018_0.json
# 543   daily_summaries_FIPS10003_jan_2018_0.json
# 581   daily_summaries_FIPS10003_jan_2018_0.json
# 615   daily_summaries_FIPS10003_jan_2018_0.json
# 656   daily_summaries_FIPS10003_jan_2018_0.json
# 693   daily_summaries_FIPS10003_jan_2018_0.json
# 735   daily_summaries_FIPS10003_jan_2018_0.json
# 778   daily_summaries_FIPS10003_jan_2018_0.json
# 824   daily_summaries_FIPS10003_jan_2018_0.json
# 863   daily_summaries_FIPS10003_jan_2018_0.json
# 901   daily_summaries_FIPS10003_jan_2018_0.json
# 938   daily_summaries_FIPS10003_jan_2018_0.json
# 978   daily_summaries_FIPS10003_jan_2018_0.json
# 1009  daily_summaries_FIPS10003_jan_2018_0.json
# 1042  daily_summaries_FIPS10003_jan_2018_0.json
# 1078  daily_summaries_FIPS10003_jan_2018_0.json
# 1114  daily_summaries_FIPS10003_jan_2018_0.json
# 1151  daily_summaries_FIPS10003_jan_2018_0.json

# %% [markdown]
# How many entries are there in the temps_min DataFrame? What are the mean, min, and max values?

# %%
# 
numOfEntries = temps_min.shape[0]
 
print('Number of Entries in temps_max : ' , numOfEntries)
# Out:
# Number of Entries in temps_max :  31

# %% [markdown]
# Graph the temps_min DataFrame

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = temps_min['date'].str[8:10]
y = temps_min['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Max Temperatues Jan 2018')]

# %% [markdown]
# We can also plot both of these lines in the same graph.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

x = temps_max['date'].str[8:10]
y = temps_max['value'] / 10

fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, temps_max['value'] / 10, color='red')
ax.plot(x, temps_min['value'] / 10, color='blue')
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min & Max Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Min & Max Temperatues Jan 2018')]
